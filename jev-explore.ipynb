# %%
from pathlib import Path
Path.cwd()
# Out:
# PosixPath('/Users/aamanlamba/Documents/Code/Jev Explore')

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.14/site-packages (from -r requirements.txt (line 1)) (7.3.0)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.14/site-packages (from -r requirements.txt (line 2)) (1.2.3)
# Requirement already satisfied: typesafe-sdk in ./.venv/lib/python3.14/site-packages (from -r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: appnope>=0.1.2 in ./.venv/lib/python3.14/site-packages (from ipykernel->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.14/site-packages (from ipykernel->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.14/site-packages (from ipykernel->-r requirements.txt (line 1)) (1.8.22)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.14/site-packages (from ipykernel->-r requirements.txt (line 1)) (9.17.1)
# Requirement already satisfied: jupyter-client>=8.9.0 in ./.venv/lib/python3.14/site-packages (from ipykernel->-r requirements.txt (line 1)) (8.10.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in ./.venv/lib/python3.14/site-packages (from ipykernel->-r requirements.txt (line 1)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.14/site-packages (from ipykernel->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in ./.venv/lib/python3.14/site-packages (from ipykernel->-r requirements.txt (line 1)) (1.7.2)
# Requirement already satisfied: packaging>=22 in ./.venv/lib/python3.14/site-packages (from ipykernel->-r requirements.txt (line 1)) (26.3)
# Requirement already satisfied: psutil>=5.7 in ./.venv/lib/python3.14/site-packages (from ipykernel->-r requirements.txt (line 1)) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in ./.venv/lib/python3.14/site-packages (from ipykernel->-r requirements.txt (line 1)) (27.2.0)
# Requirement already satisfied: tornado>=6.4.1 in ./.venv/lib/python3.14/site-packages (from ipykernel->-r requirements.txt (line 1)) (6.5.10)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.14/site-packages (from ipykernel->-r requirements.txt (line 1)) (5.16.1)
# Requirement already satisfied: httpx2>=2.0.0 in ./.venv/lib/python3.14/site-packages (from typesafe-sdk->-r requirements.txt (line 3)) (2.13.0)
# Requirement already satisfied: pydantic>=2.12.0 in ./.venv/lib/python3.14/site-packages (from typesafe-sdk->-r requirements.txt (line 3)) (2.13.5)
# Requirement already satisfied: pydantic-core>=2.41.1 in ./.venv/lib/python3.14/site-packages (from typesafe-sdk->-r requirements.txt (line 3)) (2.46.5)
# Requirement already satisfied: tenacity>=9.0.0 in ./.venv/lib/python3.14/site-packages (from typesafe-sdk->-r requirements.txt (line 3)) (9.1.4)
# Requirement already satisfied: typing-extensions>=4.13.0 in ./.venv/lib/python3.14/site-packages (from typesafe-sdk->-r requirements.txt (line 3)) (4.16.0)
# Requirement already satisfied: anyio>=4.10 in ./.venv/lib/python3.14/site-packages (from httpx2>=2.0.0->typesafe-sdk->-r requirements.txt (line 3)) (4.15.1)
# Requirement already satisfied: httpcore2==2.13.0 in ./.venv/lib/python3.14/site-packages (from httpx2>=2.0.0->typesafe-sdk->-r requirements.txt (line 3)) (2.13.0)
# Requirement already satisfied: idna>=3.18 in ./.venv/lib/python3.14/site-packages (from httpx2>=2.0.0->typesafe-sdk->-r requirements.txt (line 3)) (3.20)
# Requirement already satisfied: truststore>=0.10 in ./.venv/lib/python3.14/site-packages (from httpx2>=2.0.0->typesafe-sdk->-r requirements.txt (line 3)) (0.10.4)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.14/site-packages (from httpcore2==2.13.0->httpx2>=2.0.0->typesafe-sdk->-r requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in ./.venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in ./.venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: pexpect>4.6 in ./.venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (3.0.53)
# Requirement already satisfied: pygments>=2.14.0 in ./.venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.21.0)
# Requirement already satisfied: stack_data>=0.6.0 in ./.venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: wcwidth>=0.1.4 in ./.venv/lib/python3.14/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in ./.venv/lib/python3.14/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.14/site-packages (from jupyter-client>=8.9.0->ipykernel->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.14/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->-r requirements.txt (line 1)) (4.11.10)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.14/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.14/site-packages (from pydantic>=2.12.0->typesafe-sdk->-r requirements.txt (line 3)) (0.8.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.14/site-packages (from pydantic>=2.12.0->typesafe-sdk->-r requirements.txt (line 3)) (0.4.4)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.9.0->ipykernel->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
TYPESAFE_API_KEY = os.getenv('TYPESAFE_API_KEY')

# %%
from typesafe_sdk import Choice, Noul, Score, TypeSafeClient

client = TypeSafeClient()

ticket = "Hi, I've been trying to connect my Stripe account for 3 days and it keeps failing. I'm losing sales. Please help ASAP."

response = client.system_one(
    state=ticket,
    questions={
        "department": Choice(
            instructions="Which team should handle this",
            criteria={
                "billing": "Payment or subscription issues",
                "technical": "Bugs or integration problems",
                "sales": "Pricing or account questions",
            },
        ),
        "frustration": Score(
            instructions="How frustrated the customer appears",
            criteria=[
                "Calm, just stating facts",
                "Frustrated but civil",
                "Very angry, strong language",
            ],
        ),
        "is_urgent": Noul(
            instructions="The message conveys urgency or time-sensitivity",
        ),
    },
)

print(response.answers["department"].choice)  # "billing"
print(response.answers["frustration"].score)  # 1.035
print(response.answers["is_urgent"].noul)     # 0.999
# Out:
# billing
# 1.0
# 0.99
